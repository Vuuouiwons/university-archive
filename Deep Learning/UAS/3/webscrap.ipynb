# %%
from modules.scrapper import Scrapper
from modules.filter import Filter
from tqdm import tqdm
import pandas as pd
import threading
import time
from typing import Any
from tqdm import tqdm
from threading import Thread

# %%
scrapper = Scrapper()
filter = Filter()
lock = threading.Lock()

# %%
LINKS = {
    "liputan6": {
        "non-sepakbola": [
            "https://www.liputan6.com/tag/motogp/text",
            "https://www.liputan6.com/tag/badminton/text"
        ],
        "liga-inggris": ["https://www.liputan6.com/tag/liga-inggris/text"],
        "liga-indonesia": ["https://www.liputan6.com/tag/liga-indonesia/text"],
        "liga-spanyol": ["https://www.liputan6.com/tag/liga-spanyol/text"],
        "liga-italia": ["https://www.liputan6.com/tag/liga-italia/text"]
    },
    "detik": {
        "non-sepakbola": ["https://sport.detik.com/sport-lain/indeks"],
        "liga-inggris": ["https://sport.detik.com/sepakbola/liga-inggris/indeks"],
        "liga-indonesia": ["https://sport.detik.com/sepakbola/liga-indonesia/indeks"],
        "liga-spanyol": ["https://sport.detik.com/sepakbola/liga-spanyol/indeks"],
        "liga-italia": ["https://sport.detik.com/sepakbola/liga-italia/indeks"]
    }
}

# %%
def scrap_detik_worker(acc: dict[str, Any], url: str, label: str, news: str, filter: Filter = Filter()):
    scrapper = Scrapper()
    
    try:
        page = scrapper.scrap_url(url)
        links = filter.detik_index(page)
    except Exception as e:
        print(f"Failed to scrape index {url}: {e}")
        return  
    
    local_texts = []
    local_links = []
    
    
    def scrap_link(link):
        
        status = 'fail'
        retries = 3
        
        while status == 'fail' and retries > 0:
            try:
                text = filter.detik_article(scrapper.scrap_url(link))
                local_texts.append(text)
                local_links.append(link)
                status = 'ok'
            
            
            except Exception as e: 
                retries -= 1
                time.sleep(1) 
                if retries == 0:
                    print(f"Failed to scrape article {link} after 3 attempts.")
    
    threads = []
    for link in tqdm(links, desc=f"Scraping {label}"):
        t = threading.Thread(target=scrap_link, args=(link,) )
        t.start()
        threads.append(t)
    
    for t in threads:
        t.join()
        
    num_new_results = len(local_links)
    
    if num_new_results > 0:
        with lock:
            acc['text'].extend(local_texts)
            acc['link'].extend(local_links)
            acc['news'].extend([news] * num_new_results)
            acc['label'].extend([label] * num_new_results)

# %%
def scrap_liputan6_worker(acc: dict[str, Any], url: str, label: str, news: str, filter: Filter = Filter()):
    scrapper = Scrapper()
    
    try:
        page = scrapper.scrap_url(url)
        links = filter.liputan6_index(page)
    except Exception as e:
        print(f"Failed to scrape index {url}: {e}")
        return  

    local_texts = []
    local_links = []
    
    def scrap_link(link):
        status = 'fail'
        retries = 3
        
        while status == 'fail' and retries > 0:
            try:
                text = filter.liputan6_article(scrapper.scrap_url(link))
                local_texts.append(text)
                local_links.append(link)
                status = 'ok'
            
            
            except Exception as e: 
                retries -= 1
                time.sleep(1) 
                if retries == 0:
                    print(f"Failed to scrape article {link} after 3 attempts.")
    
    threads = []
    for link in tqdm(links, desc=f"Scraping {label}"):
        t = threading.Thread(target=scrap_link, args=(link,) )
        t.start()
        threads.append(t)

    for t in threads:
        t.join()
    
    num_new_results = len(local_links)
    
    if num_new_results > 0:
        with lock:
            acc['text'].extend(local_texts)
            acc['link'].extend(local_links)
            acc['news'].extend([news] * num_new_results)
            acc['label'].extend([label] * num_new_results)

# %%
acc_detik = dict()

acc_detik['text'] = list()
acc_detik['link'] = list()
acc_detik['news'] = list()
acc_detik['label'] = list()

news = 'detik'

threads: list[Thread] = []

for label in LINKS[news]:
    print(label)
    
    for url in LINKS[news][label]:
        
        for i in range(1, 9):
            t = threading.Thread(target=scrap_detik_worker, args=(acc_detik, f"{url}?page={i}", label, news, filter))
            t.start()
            threads.append(t)
        
for t in threads:
    t.join()
# Out:
# non-sepakbola
# liga-inggris
# liga-indonesia
# liga-spanyol
# liga-italia
# Scraping non-sepakbola:   0%|          | 0/40 [00:00<?, ?it/s]
#
#
# Scraping non-sepakbola:   5%|▌         | 2/40 [00:01<00:03, 10.46it/s]
# Scraping non-sepakbola:  10%|█         | 4/40 [00:01<00:14,  2.41it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  12%|█▎        | 5/40 [00:01<00:13,  2.65it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  15%|█▌        | 6/40 [00:04<00:33,  1.02it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  18%|█▊        | 7/40 [00:06<00:40,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  20%|██        | 8/40 [00:11<00:56,  1.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  22%|██▎       | 9/40 [00:12<01:13,  2.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  25%|██▌       | 10/40 [00:17<01:22,  2.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  28%|██▊       | 11/40 [00:19<01:19,  2.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  30%|███       | 12/40 [00:25<01:01,  2.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  32%|███▎      | 13/40 [00:26<01:30,  3.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  35%|███▌      | 14/40 [00:34<01:38,  3.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  38%|███▊      | 15/40 [00:36<01:44,  4.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  40%|████      | 16/40 [00:41<01:33,  3.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  42%|████▎     | 17/40 [00:42<01:20,  3.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping liga-inggris: 100%|██████████| 40/40 [00:40<00:00,  1.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  45%|████▌     | 18/40 [00:50<01:00,  2.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  48%|████▊     | 19/40 [00:50<01:26,  4.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  50%|█████     | 20/40 [00:52<01:02,  3.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  52%|█████▎    | 21/40 [01:01<00:51,  2.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  55%|█████▌    | 22/40 [01:02<01:19,  4.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  57%|█████▊    | 23/40 [01:10<00:59,  3.52s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  60%|██████    | 24/40 [01:11<01:18,  4.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  62%|██████▎   | 25/40 [01:19<00:53,  3.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  65%|██████▌   | 26/40 [01:20<01:10,  5.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  68%|██████▊   | 27/40 [01:21<00:48,  3.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scra
/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping liga-italia:  98%|█████████▊| 39/40 [02:33<00:03,  3.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping liga-inggris: 100%|██████████| 40/40 [02:33<00:00,  3.83s/it]
# Scraping liga-spanyol: 100%|██████████| 40/40 [02:33<00:00,  3.83s/it]
# Scraping non-sepakbola: 100%|██████████| 40/40 [02:33<00:00,  3.84s/it]
# Scraping liga-indonesia: 100%|██████████| 40/40 [02:33<00:00,  3.84s/it]
# Scraping liga-spanyol: 100%|██████████| 40/40 [02:33<00:00,  3.83s/it]
# Scraping non-sepakbola: 100%|██████████| 40/40 [02:33<00:00,  3.84s/it]
# Scraping liga-italia: 100%|██████████| 40/40 [02:33<00:00,  3.83s/it]
# Scraping liga-inggris: 100%|██████████| 40/40 [02:33<00:00,  3.83s/it]
# Scraping non-sepakbola: 100%|██████████| 40/40 [02:33<00:00,  3.84s/it]
# Scraping liga-spanyol: 100%|██████████| 40/40 [02:33<00:00,  3.83s/it]
# Scraping non-sepakbola: 100%|██████████| 40/40 [02:33<00:00,  3.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping liga-italia: 100%|██████████| 40/40 [02:33<00:00,  2.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping liga-inggris: 100%|██████████| 40/40 [02:33<00:00,  3.84s/it]
# Scraping liga-italia: 100%|██████████| 40/40 [02:33<00:00,  3.84s/it]
# Scraping liga-indonesia: 100%|██████████| 40/40 [02:33<00:00,  3.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping liga-italia: 100%|██████████| 40/40 [02:33<00:00,  3.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping liga-indonesia: 100%|██████████| 40/40 [02:34<00:00,  3.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping liga-italia: 100%|██████████| 40/40 [02:40<00:00,  4.01s/it]
# Scraping liga-indonesia: 100%|██████████| 40/40 [02:40<00:00,  4.01s/it]
# Scraping liga-indonesia: 100%|██████████| 40/40 [02:40<00:00,  4.01s/it]
# Scraping liga-spanyol: 100%|██████████| 40/40 [02:40<00:00,  4.01s/it]

# %%
df = pd.DataFrame(acc_detik)
df.head()
df.to_csv('./detik-data.csv')

# %%
acc_liputan6 = dict()

acc_liputan6['text'] = list()
acc_liputan6['link'] = list()
acc_liputan6['news'] = list()
acc_liputan6['label'] = list()

news = 'liputan6'

threads: list[Thread] = []

for label in LINKS[news]:
    print(label)
    
    for url in LINKS[news][label]:
        
        for i in range(1, 9):
            t = threading.Thread(target=scrap_liputan6_worker, args=(acc_liputan6, f"{url}?page={i}", label, news, filter))
            t.start()
            threads.append(t)
        

for t in threads:
    t.join()
# Out:
# non-sepakbola
# liga-inggris
# liga-indonesia
# liga-spanyol
# liga-italia
# Scraping non-sepakbola:  71%|███████▏  | 15/21 [00:00<00:00, 123.72it/s]
# Scraping non-sepakbola: 100%|██████████| 21/21 [00:03<00:00,  6.95it/s]
# Scraping non-sepakbola:   0%|          | 0/21 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:   5%|▍         | 1/21 [00:00<00:02,  7.11it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scraping non-sepakbola:  10%|▉         | 2/21 [00:01<00:03,  5.41it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scra