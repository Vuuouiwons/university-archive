# %%
import pandas as pd

# %%
df = pd.read_csv('./dataset/detik-data.csv', index_col='index')
df = df.drop_duplicates()

df.head()
# Out:
#                                                     text  \
# index
# 0      Chelseasepertinya masih butuh sosok striker ha...
# 2      Tottenham Hotspur vs Manchester Unitedtuntas d...
# 3      Florian Wirtzmasih belum menunjukkan performa ...
# 6      Pep Guardiolamemang bergelimang gelar selama k...
# 7      ManajerManchester UnitedRuben Amorimtidak risa...
#
#                                                     link   news         label
# index
# 0      https://sport.detik.com/sepakbola/liga-inggris...  detik  liga-inggris
# 2      https://sport.detik.com/sepakbola/liga-inggris...  detik  liga-inggris
# 3      https://sport.detik.com/sepakbola/liga-inggris...  detik  liga-inggris
# 6      https://sport.detik.com/sepakbola/liga-inggris...  detik  liga-inggris
# 7      https://sport.detik.com/sepakbola/liga-inggris...  detik  liga-inggris

# %%
df.to_csv('./detik-data.csv')

# %%
df = pd.read_csv('./dataset/liputan6-data.csv', index_col='index')
df = df.drop_duplicates()

df.head()
# Out:
#                                                     text  \
# index
# 0      Liputan6.com, Jakarta -GelaranPertaminaGrand P...
# 1      Liputan6.com, Lombok -Di tengah hiruk pikukPer...
# 2      Liputan6.com, Jakarta -MaskapaiCitilinkmemasti...
# 3      Liputan6.com, Jakarta -PersainganMotoGP Indone...
# 4      Liputan6.com, Lombok -SuasanaPertaminaGrand Pr...
#
#                                                     link      news  \
# index
# 0      https://www.liputan6.com/otomotif/read/6175797...  liputan6
# 1      https://www.liputan6.com/otomotif/read/6175980...  liputan6
# 2      https://www.liputan6.com/bisnis/read/6176038/s...  liputan6
# 3      https://www.liputan6.com/bola/read/6175481/jad...  liputan6
# 4      https://www.liputan6.com/otomotif/read/6175442...  liputan6
#
#                label
# index
# 0      non-sepakbola
# 1      non-sepakbola
# 2      non-sepakbola
# 3      non-sepakbola
# 4      non-sepakbola

# %%
df.to_csv('./liputan6-data.csv')
