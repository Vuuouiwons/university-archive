# %%
import pandas as pd

# %%
df_detik = pd.read_csv('./dataset/detik-data.csv', index_col='index')
df_liputan6 = pd.read_csv('./dataset/liputan6-data.csv', index_col='index')

# %%
df_merged = pd.concat([df_detik, df_liputan6], ignore_index=True)

# %%
df_merged.to_csv('./dataset/dataset.csv')
