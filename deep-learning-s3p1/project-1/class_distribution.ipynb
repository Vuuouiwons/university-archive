# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import torch

def count_classes_from_dirs(base_path: str):
    class_counts = {}
    for cls in os.listdir(base_path):
        cls_path = os.path.join(base_path, cls)
        if os.path.isdir(cls_path):
            n = len(os.listdir(cls_path))
            class_counts[cls] = n
    return class_counts

# e.g.
train_base = "dataset/train"
counts = count_classes_from_dirs(train_base)
print(counts)

# Plot
plt.figure(figsize=(8, 5))
sns.barplot(x=list(counts.keys()), y=list(counts.values()))
plt.xticks(rotation=45)
plt.ylabel("Jumlah Gambar")
plt.title("Distribusi class di dataset train sebelum augmentasi")
plt.tight_layout()
plt.show()
# Out:
# {'angry': 3995, 'disgust': 436, 'fear': 4097, 'happy': 7215, 'neutral': 4965, 'sad': 4830, 'surprise': 3171}

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns

def count_classes_from_dirs(base_path: str):
    class_counts = {}
    for cls in os.listdir(base_path):
        cls_path = os.path.join(base_path, cls)
        if os.path.isdir(cls_path):
            n = len(os.listdir(cls_path))
            class_counts[cls] = n
    return class_counts

# e.g.
train_base = "augmented_dataset/train"
counts = count_classes_from_dirs(train_base)
print(counts)

# Plot
plt.figure(figsize=(8, 5))
sns.barplot(x=list(counts.keys()), y=list(counts.values()))
plt.xticks(rotation=45)
plt.ylabel("Jumlah Gambar")
plt.title("Distribusi class di dataset train setelah augmentasi")
plt.tight_layout()
plt.show()

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import torch

def count_classes_from_dirs(base_path: str):
    class_counts = {}
    for cls in os.listdir(base_path):
        cls_path = os.path.join(base_path, cls)
        if os.path.isdir(cls_path):
            n = len(os.listdir(cls_path))
            class_counts[cls] = n
    return class_counts

# e.g.
train_base = "dataset/test"
counts = count_classes_from_dirs(train_base)
print(counts)

# Plot
plt.figure(figsize=(8, 5))
sns.barplot(x=list(counts.keys()), y=list(counts.values()))
plt.xticks(rotation=45)
plt.ylabel("Jumlah Gambar")
plt.title("Distribusi class di dataset split test")
plt.tight_layout()
plt.show()
# Out:
# {'angry': 958, 'disgust': 111, 'fear': 1024, 'happy': 1774, 'neutral': 1233, 'sad': 1247, 'surprise': 831}
